# %%
a = 2

# %%
a

# %%
a+6

# %%
! pip install pandas

# %%
from CustomerDAO import CustomerDAO

# %%
dao = CustomerDAO(r'..\customers_db.db')
list(dao.find_all())

# %%
import pandas as pd 
df = pd.DataFrame(dao.find_all())
df
# Out:
#        id first_name  last_name                        email  gender  \
# 0       1   Martynne    Bullock    mbullock0@paginegialle.it  Female
# 1       2   Bethanne    Padbury       bpadbury1@blogspot.com  Female
# 2       3   Devondra   Rubinsky            drubinsky2@hp.com  Female
# 3       4        Peg   Iglesias          piglesias3@hibu.com  Female
# 4       5     Sybila    Kunisch     skunisch4@soundcloud.com  Female
# ..    ...        ...        ...                          ...     ...
# 995   996     Veriee   Chinnock      vchinnockrn@oaic.gov.au  Female
# 996   997  Gilemette  Swaysland         gswayslandro@icq.com  Female
# 997   998   Rosmunda    Dulwich  rdulwichrp@wunderground.com  Female
# 998   999      Gerri    Pinkard   gpinkardrq@sourceforge.net  Female
# 999  1000        Wes   Chandlar             wchandlarrr@g.co    Male
#
#           ip_address
# 0    211.250.159.124
# 1     100.189.34.233
# 2        143.3.240.2
# 3       1.183.19.248
# 4    207.163.236.228
# ...
